# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
time = np.load('./time_2827_110100.npy')
voltage = np.load('./volts_2827_110100.npy')
blocks = np.load('./blocks_2827_110100.npy')
voltage_final = np.load('./volts_2827_80111.npy')
time_final = np.load('./time_2827_110110.npy')

# %%
from scipy import optimize

def SineFit(t,v,freq):
    params, params_covariance = optimize.curve_fit(SineFunc,t,v,p0=[freq,np.pi/2.0,350])#,bounds=([-np.inf,-np.inf,200],[np.inf,np.inf,np.inf]))#freq,offset,amplitude,voff
    if(params[2]<0):
        params[2]=np.abs(params[2])
        params[1]=params[1]+np.pi
    params[1]=params[1]%(np.pi*2)
    while(params[1]<0):
        params[1]=params[1]+np.pi*2.0
    return(params)
def SineFunc(t,k,phi,A): #time, freq, offset, amplitude
    return A*np.sin(2*np.pi*k*t-phi)

# %%
params=SineFit(time[1][1::2],voltage[1][1::2],0.218)
params

plt.scatter(time[1][1::2], voltage[1][1::2], label='Data')
# plt.scatter(time_final[1][1::2], voltage[1][1::2], label='Data')

plt.plot(time[1],SineFunc(time[1],params[0],params[1],params[2]),label='Fitted function')
# plt.plot(time_final[0]+time[1][0],voltage_final[1],"--")
plt.xlim(50,80)
# Out:
# (50, 80)

# %% [markdown]
# # Debug

# %%
# plt.plot(time[0][1::2],voltage[0][1::2],label="No calibration")
# plt.plot(time_final[0][1]+time[0][1],voltage[0],"." ,label="time-only calibration")
# plt.plot(time_final[0],voltage[0][1::2])
# plt.xlim(50,80)
np.shape(time)
# plt.plot(time[0])
# Out:
# (2220, 896)

# %%
plt.plot(time[1],voltage[1], ".",label="No calibration")
# plt.plot(time_final[1]+time[1][0],voltage[1],"." ,label="time-only calibration")
# plt.plot(time_final[1]+time[1][0],voltage_final[1],".",label="time+voltage calibration")
plt.plot(time[1], SineFunc(time[1],params[0],params[1],params[2]),label='data-fitted sine', alpha=0.6)
plt.legend(bbox_to_anchor=(1.2, 1.2), loc='upper right', ncol=1)
plt.title("A4, Run 2827, event 0, ch8", loc="left", fontsize=13)
plt.ylabel("ADC count")
plt.xlabel("Time [ns]")
plt.xlim(50,80)
plt.tight_layout()
# plt.savefig("calib_Run2827_ev0_ch8.png", dpi=200)

# %%
from scipy import optimize

# %%
def SineFit(t,v,freq):
    params, params_covariance = optimize.curve_fit(SineFunc,t,v,p0=[freq,np.pi/2.0,350])#,bounds=([-np.inf,-np.inf,200],[np.inf,np.inf,np.inf]))#freq,offset,amplitude,voff
    if(params[2]<0):
        params[2]=np.abs(params[2])
        params[1]=params[1]+np.pi
    params[1]=params[1]%(np.pi*2)
    while(params[1]<0):
        params[1]=params[1]+np.pi*2.0
    return(params)
def SineFunc(t,k,phi,A): #time, freq, offset, amplitude
    return A*np.sin(2*np.pi*k*t-phi)

# %%
params=SineFit(time[0],voltage[0],0.218)
params
# Out:
# array([2.17926524e-01, 4.51453801e+00, 5.04479079e+02])

# %%
plt.scatter(time[0][1::2], voltage[0][1::2], label='Data')
plt.plot(time[1],SineFunc(time[1],params[0],params[1],params[2]),label='Fitted function')
# plt.plot(time_final[0]+time[1][0],voltage_final[1],"--")
plt.xlim(50,80)
# Out:
# (50, 80)
